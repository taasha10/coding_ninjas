# %%
#lecture 2 practice

# %%
import pandas as pd
titanic = pd.read_csv("titanic_train.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# 5          False     False   False  False  False   True  False  False   False
# 6          False     False   False  False  False  False  False  False   False
# 7          False     False   False  False  False  False  False  False   False
# 8          False     False   False  False  False  False  False  False   False
# 9          False     False   False  False  False  False  False  False   False
# 10         False     False   False  False  False  False  False  False   False
# ...

# %%
titanic.iloc[1:3,2:4]
# Out:
#    Pclass                                               Name
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3                             Heikkinen, Miss. Laina

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
del titanic["PassengerId"]
del titanic["Name"]

# %%
titanic
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket      Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171    7.2500
# 1           1       1  female  38.0      1      0          PC 17599   71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282    7.9250
# 3           1       1  female  35.0      1      0            113803   53.1000
# 4           0       3    male  35.0      0      0            373450    8.0500
# 5           0       3    male   NaN      0      0            330877    8.4583
# 6           0       1    male  54.0      0      0             17463   51.8625
# 7           0       3    male   2.0      3      1            349909   21.0750
# 8           1       3  female  27.0      0      2            347742   11.1333
# 9           1       2  female  14.0      1      0            237736   30.0708
# 10          1       3  female   4.0      1      1           PP 9549   16.7000
# ...

# %%
titanic.Age.fillna(titanic.Age.mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
# 5      29.699118
# 6      54.000000
# 7       2.000000
# 8      27.000000
# 9      14.000000
# 10      4.000000
# 11     58.000000
# 12     20.000000
# 13     39.000000
# 14     14.000000
# 15     55.000000
# 16      2.000000
# 17     29.699118
# 18     31.000000
# 19     29.699118
# 20     35.000000
# 21     34.000000
# 22     15.000000
# 23     28.000000
# 24      8.000000
# 25     38.000000
# 26     29.699118
# 27     19.000000
# 28     29.699118
# 29     29.699118
#          ...
# 861    21.000000
# 862    48.000000
# 863    29.699118
# 864    24.000000
# 865    42.000000
# 866    27.000000
# 867    31.000000
# 868    29.699118
# 869     4.000000
# 870    26.000000
# 871    47.000000
# 872    33.000000
# 873    47.000000
# 874    28.000000
# 875    15.000000
# 876    20.000000
# 877    19.000000
# 878    29.699118
# 879    56.000000
# 880    25.000000
# 881    33.000000
# ...

# %%
titanic.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
import matplotlib.pyplot as plt
x=[1,2,3]
y=[2,6,7]
plt.plot(x,y)
plt.title("Demo")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.legend("X")
#plt.ylegend("Y=1")
plt.show()

# %%
x=[1,2,3]
y=[2,6,7]
plt.bar(x,y,color="r") #or red
plt.show()

# %%
x=[1,2,3]
y=[2,6,7]
plt.scatter(x,y,color="b")
plt.show()

# %%
x=titanic.Age
y=titanic.Survived
plt.bar(x,y,color="red")
plt.show()

# %%
def getnum(sex):
    if(sex=="male"):
        return 1
    else:
        return 2
titanic["Gender"]=titanic["Sex"].apply(getnum)
titanic
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch            Ticket      Fare  \
# 0           0       3    2  22.0      1      0         A/5 21171    7.2500
# 1           1       1    2  38.0      1      0          PC 17599   71.2833
# 2           1       3    2  26.0      0      0  STON/O2. 3101282    7.9250
# 3           1       1    2  35.0      1      0            113803   53.1000
# 4           0       3    2  35.0      0      0            373450    8.0500
# 5           0       3    2   NaN      0      0            330877    8.4583
# 6           0       1    2  54.0      0      0             17463   51.8625
# 7           0       3    2   2.0      3      1            349909   21.0750
# 8           1       3    2  27.0      0      2            347742   11.1333
# 9           1       2    2  14.0      1      0            237736   30.0708
# 10          1       3    2   4.0      1      1           PP 9549   16.7000
# ...

# %%
del titanic["Sex"]

# %%
titanic
# Out:
#      Survived  Pclass   Age  SibSp  Parch            Ticket      Fare  \
# 0           0       3  22.0      1      0         A/5 21171    7.2500
# 1           1       1  38.0      1      0          PC 17599   71.2833
# 2           1       3  26.0      0      0  STON/O2. 3101282    7.9250
# 3           1       1  35.0      1      0            113803   53.1000
# 4           0       3  35.0      0      0            373450    8.0500
# 5           0       3   NaN      0      0            330877    8.4583
# 6           0       1  54.0      0      0             17463   51.8625
# 7           0       3   2.0      3      1            349909   21.0750
# 8           1       3  27.0      0      2            347742   11.1333
# 9           1       2  14.0      1      0            237736   30.0708
# 10          1       3   4.0      1      1           PP 9549   16.7000
# 11          1       1  58.0      0      0            113783   26.5500
# ...

# %%
srv = titanic[titanic.Survived == 1]
fsrv = titanic[titanic.Gender == 2]
fpsrv = fsrv[fsrv.Parch >0].sum()
print(fsrv)
fpsrv
# Out:
#      Survived  Pclass   Age  SibSp  Parch            Ticket      Fare Cabin  \
# 1           1       1  38.0      1      0          PC 17599   71.2833   C85
# 2           1       3  26.0      0      0  STON/O2. 3101282    7.9250   NaN
# 3           1       1  35.0      1      0            113803   53.1000  C123
# 8           1       3  27.0      0      2            347742   11.1333   NaN
# 9           1       2  14.0      1      0            237736   30.0708   NaN
# 10          1       3   4.0      1      1           PP 9549   16.7000    G6
# 11          1       1  58.0      0      0            113783   26.5500  C103
# 14          0       3  14.0      0      0            350406    7.8542   NaN
# 15          1       2  55.0      0      0            248706   16.0000   NaN
# 18          0       3  31.0      1      0            345763   18.0000   NaN
# 19          1       3   NaN      0      0              2649    7.2250   NaN
# ...

# %%
fsibsp = fsrv[fsrv.SibSp>0].sum()
fsibsp
# Out:
# Survived                                                   96
# Pclass                                                    298
# Age                                                      3163
# SibSp                                                     218
# Parch                                                     123
# Ticket      PC 17599113803237736PP 9549345763349909347077P...
# Fare                                                  7222.45
# Embarked    CSCSSSSCSCSSCSCSSSSSSQCSSCSSSSSSSSQSCSSSCQSSSC...
# Gender                                                    280
# dtype: object

# %%
import numpy as np
fsibpar = fsrv[np.logical_and(fsrv.SibSp > 0, fsrv.Parch > 0)].sum()
fsibpar
# Out:
# Survived                                                   42
# Pclass                                                    167
# Age                                                    1470.5
# SibSp                                                     143
# Parch                                                     123
# Ticket      PP 9549349909347077SC/Paris 2123C.A. 346513101...
# Fare                                                  4034.22
# Embarked    SSSCSSSSSCSSSSSSSSSCSCSSSSSSSSSSSCCSSSSSSSSCSC...
# Gender                                                    144
# dtype: object
