# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
SAMPLE_TEXT = "Does this thing really work? Lets see."

# %%
sent_tokenize(SAMPLE_TEXT)
# Out:
# ['Does this thing really work?', 'Lets see.']

# %%
words = word_tokenize(SAMPLE_TEXT)
words
# Out:
# ['Does', 'this', 'thing', 'really', 'work', '?', 'Lets', 'see', '.']

# %%
from nltk.corpus import stopwords

# %%
stop = stopwords.words('english')
stop
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
clean_words = [w for w in words if not w.lower() in stop]
clean_words
# Out:
# ['thing', 'really', 'work', '?', 'Lets', 'see', '.']

# %%
stem_words = ["play", "played", "playing", "player", "happier"]
from nltk.stem import PorterStemmer
ps = PorterStemmer()
for w in stem_words:
    print (ps.stem(w))
# Out:
# play
# play
# play
# player
# happier

# %%
from nltk.corpus import state_union

# %%
text = state_union.raw("2006-GWBush.txt")

# %%
text
# Out:
# 'PRESIDENT GEORGE W. BUSH\'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS ON THE STATE OF THE UNION\n \nJanuary 31, 2006\n\nTHE PRESIDENT: Thank you all. Mr. Speaker, Vice President Cheney, members of Congress, members of the Supreme Court and diplomatic corps, distinguished guests, and fellow citizens: Today our nation lost a beloved, graceful, courageous woman who called America to its founding ideals and carried on a noble dream. Tonight we are comforted by the hope of a glad reunion with the husband who was taken so long ago, and we are grateful for the good life of Coretta Scott King. (Applause.)\n\nPresident George W. Bush reacts to applause during his State of the Union Address at the Capitol, Tuesday, Jan. 31, 2006. White House photo by Eric DraperEvery time I\'m invited to this rostrum, I\'m humbled by the privilege, and mindful of the history we\'ve seen together. We have gathered under this Capitol dome in moments of national mourning and national achievement. We have served America through one of the most consequential periods of our history -- and it has been my honor to serve with you.\n\nIn a system of two parties, two chambers, and two elected branches, there will always be differences and debate. But even tough debates can be conducted in a civil tone, and our differences cannot be allowed to harden into anger. To confront the great issues before us, we must act in a spirit of goodwill and respect for one another -- and I will do my part. Tonight the state of our Union is strong -- and together we will make it stronger. (Applause.)\n\nIn this decisive year, you and I will make choices that determine both the future and the character of our country. We will choose to act confidently in pursuing the enemies of freedom -- or retreat from our duties in the hope of an easier life. We will choose to build our prosperity by leading the world economy -- or shut ourselves off from trade and opportunity. In a complex and challenging time, the road of isolationism and protectionism may seem broad and inviting -- yet it ends in danger and decline. The only way to protect our people, the only way to secure the peace, the only way to control our destiny is by our leadership -- so the United States of America will continue to lead. (Applause.)\n\nAbroad, our nation is committed to an historic, long-term goal -- we seek the end of tyranny in our world. Some dismiss that goal as misguided idealism. In reality, the future security of America depends on it. On September the 11th, 2001, we found that problems originating in a failed and oppressive state 7,000 miles away could bring murder and destruction to our country. Dictatorships shelter terrorists, and feed resentment and radicalism, and seek weapons of mass destruction. Democracies replace resentment with hope, respect the rights of their citizens and their neighbors, and join the fight against terror. Every step toward freedom in the world makes our country safer -- so we will act boldly in freedom\'s cause. (Applause.)\n\nFar from being a hopeless dream, the advance of freedom is the great story of our time. In 1945, there were about two dozen lonely democracies in the world. Today, there are 122. And we\'re writing a new chapter in the story of self-government -- with women lining up to vote in Afghanistan, and millions of Iraqis marking their liberty with purple ink, and men and women from Lebanon to Egypt debating the rights of individuals and the necessity of freedom. At the start of 2006, more than half the people of our world live in democratic nations. And we do not forget the other half -- in places like Syria and Burma, Zimbabwe, North Korea, and Iran -- because the demands of justice, and the peace of this world, require their freedom, as well. (Applause.)\n\nPresident George W. Bush delivers his State of the Union Address at the Capitol, Tuesday, Jan. 31, 2006. White House photo by Eric Draper No one can deny the success of freedom, but some men rage and figh ...

# %%
from nltk import pos_tag

# %%
pos = pos_tag(word_tokenize(text.lower()))
pos[0:50]
# Out:
# [('president', 'NN'),
#  ('george', 'NN'),
#  ('w.', 'VBD'),
#  ('bush', 'NN'),
#  ("'s", 'POS'),
#  ('address', 'NN'),
#  ('before', 'IN'),
#  ('a', 'DT'),
#  ('joint', 'JJ'),
#  ('session', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('congress', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('state', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('union', 'NN'),
#  ('january', 'NN'),
#  ('31', 'CD'),
#  (',', ','),
#  ('2006', 'CD'),
#  ('the', 'DT'),
#  ('president', 'NN'),
#  (':', ':'),
#  ('thank', 'NN'),
#  ('you', 'PRP'),
#  ('all', 'DT'),
#  ('.', '.'),
#  ('mr.', 'NN'),
#  ('speaker', 'NN'),
#  (',', ','),
#  ('vice', 'NN'),
#  ('president', 'NN'),
#  ('cheney', 'NN'),
#  (',', ','),
#  ('members', 'NNS'),
#  ('of', 'IN'),
#  ('congress', 'NN'),
#  (',', ','),
#  ('members', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('supreme', 'JJ'),
#  ('court', 'NN'),
#  ('and', 'CC'),
#  ('diplomatic', 'JJ'),
#  ('corps', 'NN'),
#  (',', ',')]

# %% [raw]
# POS tag list:
#
# CC	coordinating conjunction
# CD	cardinal digit
# DT	determiner
# EX	existential there (like: "there is" ... think of it like "there exists")
# FW	foreign word
# IN	preposition/subordinating conjunction
# JJ	adjective	'big'
# JJR	adjective, comparative	'bigger'
# JJS	adjective, superlative	'biggest'
# LS	list marker	1)
# MD	modal	could, will
# NN	noun, singular 'desk'
# NNS	noun plural	'desks'
# NNP	proper noun, singular	'Harrison'
# NNPS	proper noun, plural	'Americans'
# PDT	predeterminer	'all the kids'
# POS	possessive ending	parent's
# PRP	personal pronoun	I, he, she
# PRP$	possessive pronoun	my, his, hers
# RB	adverb	very, silently,
# RBR	adverb, comparative	better
# RBS	adverb, superlative	best
# RP	particle	give up
# TO	to	go 'to' the store.
# UH	interjection	errrrrrrrm
# VB	verb, base form	take
# VBD	verb, past tense	took
# VBG	verb, gerund/present participle	taking
# VBN	verb, past participle	taken
# VBP	verb, sing. present, non-3d	take
# VBZ	verb, 3rd person sing. present	takes
# WDT	wh-determiner	which
# WP	wh-pronoun	who, what
# WP$	possessive wh-pronoun	whose
# WRB	wh-abverb	where, when

# %%
from nltk.stem import WordNetLemmatizer

# %%
lem = WordNetLemmatizer()

# %%
t = "good"
lem.lemmatize(t, pos = 'a')
# Out:
# 'good'

# %%
t = "better"
t=lem.lemmatize(t, pos = 'a')
t
# Out:
# 'good'

# %%
lem.lemmatize("painting", pos = 'n')
# Out:
# 'painting'

# %%
lem.lemmatize("painting", pos = 'v')
# Out:
# 'paint'

# %%
from nltk.corpus import wordnet

# %%
w1 = wordnet.synset("ship.n.01")
w2 = wordnet.synset("boat.n.01")
w1.wup_similarity(w2)
# Out:
# 0.9090909090909091

# %%
from nltk import ne_chunk

# %%
sentence = "Mr. Mark Zuckerberg is the founder of the Facebook inc."
ne_chunk(pos_tag(word_tokenize(sentence.lower())))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     334             method = get_real_method(obj, self.print_method)
#     335             if method is not None:
# --> 336                 return method()
#     337             return None
#     338         else:
#
# ~/anaconda3/lib/python3.6/site-packages/nltk/tree.py in _repr_png_(self)
#     728             _canvas_frame.print_to_file(in_path)
#     729             _canvas_frame.destroy_widget(widget)
# --> 730             subprocess.call([find_binary('gs', binary_names=['gswin32c.exe', 'gswin64c.exe'], env_vars=['PATH'], verbose=False)] +
#     731                             '-q -dEPSCrop -sDEVICE=png16m -r90 -dTextAlphaBits=4 -dGraphicsAlphaBits=4 -dSAFER -dBATCH -dNOPAUSE -sOutputFile={0:} {1:}'
#     732                             .format(out_path, in_path).split())
#
# ~/anaconda3/lib/python3.6/site-packages/nltk/__init__.py in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     602                 binary_names=None, url=None, verbose=False):
#     603     return next(find_binary_iter(name, path_to_bin, env_vars, searchpath,
# --> 604                                  binary_names, url, verbose))
#     605
#     606 def find_jar_iter(name_pattern, path_to_jar=None, env_vars=(),
#
# ~/anaconda3/lib/python3.6/site-packages/nltk/__init__.py in find_binary_iter(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     596     """
#     597     for file in  find_file_iter(path_to_bin or name, env_vars, searchpath, binary_names,
# --> 598                      url, verbose):
#     599         yield file
#     600
#
# ~/anaconda3/lib/python3.6/site-packages/nltk/__init__.py in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     567                         (filename, url))
#     568         div = '='*75
# --> 569         raise LookupError('\n\n%s\n%s\n%s' % (div, msg, div))
#     570
#     571
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the gs file!
# Use software specific configuration paramaters or set the PATH environment variable.
# ===========================================================================
# Tree('S', [Tree('PERSON', [('mr.', 'NN')]), ('mark', 'NNP'), ('zuckerberg', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('founder', 'NN'), ('of', 'IN'), ('the', 'DT'), ('facebook', 'NN'), ('inc', 'NN'), ('.', '.')])

# %%
from nltk.corpus import movie_reviews

# %%
len(movie_reviews.fileids('neg'))
# Out:
# 1000

# %%
movie_reviews.words(movie_reviews.fileids()[5])
# Out:
# ['capsule', ':', 'in', '2176', 'on', 'the', 'planet', ...]

# %%
documents = []
for category in movie_reviews.categories():
    for fileid in movie_reviews.fileids(category):
        documents.append((movie_reviews.words(fileid), category))
documents[0:5]
# Out:
# [(['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...], 'neg'),
#  (['the', 'happy', 'bastard', "'", 's', 'quick', 'movie', ...], 'neg'),
#  (['it', 'is', 'movies', 'like', 'these', 'that', 'make', ...], 'neg'),
#  (['"', 'quest', 'for', 'camelot', '"', 'is', 'warner', ...], 'neg'),
#  (['synopsis', ':', 'a', 'mentally', 'unstable', 'man', ...], 'neg')]

# %%
import random
random.seed(0)
random.shuffle(documents)

# %%
training_documents = documents[0:1500]
testing_documents = documents[1500:]

# %%
import string
punc = list(string.punctuation)
all_words = []
stop = stop + punc + ['movie','film','--']
for doc in training_documents:
    for w in doc[0]:
        if w.lower() not in stop:
            all_words.append(w.lower())

# %%
len(all_words)
# Out:
# 516280

# %%
import nltk
dist = nltk.FreqDist(all_words)
features = dist.most_common(3000)
feature_words = [i[0] for i in features]
feature_words
# Out:
# ['one',
#  'like',
#  'even',
#  'time',
#  'good',
#  'story',
#  'would',
#  'much',
#  'also',
#  'character',
#  'get',
#  'well',
#  'two',
#  'characters',
#  'first',
#  'see',
#  'way',
#  'make',
#  'life',
#  'plot',
#  'little',
#  'films',
#  'really',
#  'people',
#  'could',
#  'scene',
#  'man',
#  'bad',
#  'never',
#  'best',
#  'new',
#  'many',
#  'scenes',
#  'action',
#  'director',
#  'movies',
#  'know',
#  'great',
#  'go',
#  'made',
#  'love',
#  'another',
#  'us',
#  'something',
#  'world',
#  'big',
#  'back',
#  'work',
#  'end',
#  'makes',
#  'still',
#  'seems',
#  'however',
#  'real',
#  'better',
#  'every',
#  'enough',
#  'take',
#  'seen',
#  'audience',
#  'though',
#  'around',
#  'going',
#  'year',
#  'funny',
#  'may',
#  'gets',
#  'old',
#  'performance',
#  'comedy',
#  'look',
#  'think',
#  'years',
#  'long',
#  'role',
#  'actually',
#  'say',
#  'nothing',
#  'things',
#  'last',
#  'john',
#  'right',
#  'thing',
#  'come',
#  'find',
#  'almost',
#  'although',
#  'ever',
#  'played',
#  'fact',
#  'star',
#  'script',
#  'plays',
#  'show',
#  'young',
#  'screen',
#  'since',
#  'comes',
#  'cast',
#  'actors',
#  'without',
#  'day',
#  'guy',
#  'three',
#  'point',
#  'part',
#  'lot',
#  'quite',
#  'original',
#  'acting',
#  'course',
#  'effects',
#  'least',
#  'away',
#  'might',
#  'must',
#  'family',
#  'far',
#  'takes',
#  'minutes',
#  'rather',
#  'goes',
#  'high',
#  'anything',
#  'interesting',
#  'watch',
#  'set',
#  'place',
#  'fun',
#  'special',
#  'times',
#  'yet',
#  'making',
#  'seem',
#  'hollywood',
#  'wife',
#  'hard',
#  'trying',
#  'always',
#  'instead',
#  'bit',
#  'series',
#  'sense',
#  'along',
#  'job',
#  'give',
#  'picture',
#  'actor',
#  'woman',
#  'want',
#  'american',
#  'home',
#  'black',
#  'kind',
#  'men',
#  'half',
#  'everything',
#  'become',
#  'sure',
#  'together',
#  'help',
#  'dialogue',
#  'money',
#  'probably',
#  'gives',
#  'becomes',
#  'watching',
#  'feel',
#  'whole',
#  'looking',
#  'perhaps',
#  'father',
#  'music',
#  'city',
#  'pretty',
#  '10',
#  'everyone',
#  'wants',
#  'less',
#  'horror',
#  'given',
#  'mind',
#  'done',
#  'moments',
#  'sex',
#  '2',
#  'especially',
#  'death',
#  'got',
#  'girl',
#  'evil',
#  'let',
#  'next',
#  'play',
#  'put',
#  'james',
#  'line',
#  'michael',
#  'humor',
#  'friend',
#  'mother',
#  'reason',
#  'completely',
#  'whose',
#  'simply',
#  'soon',
#  'anyone',
#  'couple',
#  'small',
#  'looks',
#  'left',
#  'human',
#  'true',
#  'night',
#  'case',
#  'several',
#  'name',
#  'second',
#  'different',
#  'someone',
#  'performances',
#  'entire',
#  'called',
#  'begins',
#  'problem',
#  'getting',
#  'dead',
#  'main',
#  'thought',
#  'rest',
#  'found',
#  'tv',
#  'comic',
#  'based',
#  'ending',
#  'written',
#  'stars',
#  'top',
#  'david',
#  'school',
#  'lost',
#  'else',
#  'turns',
#  'shows',
#  'often',
#  'believe',
#  'alien',
#  'group',
#  'wrong',
#  'idea',
#  'use',
#  'house',
#  'named',
#  'used',
#  'friends',
#  'final',
#  'either',
#  'head',
#  'son',
#  'later',
#  'hand',
#  'behind',
#  'run',
#  'relationship',
#  'tries',
#  'hour',
#  'unfortunately',
#  'nice',
#  'live',
#  'sequence',
#  'playing',
#  'despite',
#  'full',
#  'style',
#  'turn',
#  'face',
#  'certainly',
#  'town',
#  'boy',
#  'tell',
#  'seeing',
#  'works',
#  'keep',
#  'white',
#  'shot',
#  'war',
#  'finds',
#  'book',
#  'person',
#  'lives',
#  'finally',
#  'video',
#  'days',
#  'maybe',
#  'side',
#  'said',
#  'moment',
#  'kids',
#  'able',
#  'fight',
#  'earth',
#  'worst',
#  'camera',
#  'running',
#  'game',
#  'perfect',
#  'children',
#  'mr',
#  'directed',
#  'lines',
#  'including',
#  'dark',
#  'kevin',
#  'nearly',
#  'writer',
#  'disney',
#  'daughter',
#  'care',
#  'past',
#  'entertaining',
#  'car',
#  'worth',
#  'self',
#  'starts',
#  'upon',
#  'supposed',
#  'known',
#  'matter',
#  'robert',
#  'screenplay',
#  'major',
#  'summer',
#  'violence',
#  'king',
#  'beautiful',
#  'short',
#  'early',
#  'act',
#  'example',
#  'start',
#  'need',
#  'killer',
#  'try',
#  'title',
#  'team',
#  'review',
#  'deep',
#  'sequences',
#  'production',
#  'exactly',
#  'coming',
#  'eyes',
#  'voice',
#  'sort',
#  'heart',
#  'joe',
#  'jackie',
#  'drama',
#  'brother',
#  'jokes',
#  'problems',
#  'five',
#  'fine',
#  'opening',
#  'women',
#  'classic',
#  'hero',
#  'jack',
#  'order',
#  'already',
#  'kill',
#  'direction',
#  'others',
#  'sometimes',
#  'hit',
#  '1',
#  'obvious',
#  'lee',
#  'save',
#  'close',
#  'york',
#  'four',
#  'simple',
#  'knows',
#  'stop',
#  'girls',
#  'question',
#  'level',
#  'fans',
#  'truly',
#  'note',
#  'dog',
#  'guys',
#  'throughout',
#  'room',
#  'ends',
#  'child',
#  'dr',
#  'yes',
#  'tom',
#  'beginning',
#  'fiction',
#  'smith',
#  'strong',
#  'attempt',
#  'possible',
#  'roles',
#  'scream',
#  'boring',
#  'piece',
#  'hope',
#  'genre',
#  'peter',
#  'supporting',
#  'eventually',
#  'version',
#  'space',
#  'says',
#  'husband',
#  'mean',
#  'career',
#  'emotional',
#  'oscar',
#  'body',
#  'manages',
#  'tells',
#  'wonder',
#  'thriller',
#  'feature',
#  'romantic',
#  'novel',
#  'laugh',
#  'fall',
#  '3',
#  'elements',
#  'sets',
#  'worse',
#  'happens',
#  'saw',
#  'meet',
#  'de',
#  'stupid',
#  'quickly',
#  'mostly',
#  'laughs',
#  'george',
#  'involving',
#  'result',
#  'police',
#  'murder',
#  'batman',
#  'sound',
#  'lack',
#  'experience',
#  'hell',
#  'involved',
#  'chris',
#  'single',
#  'lead',
#  'bring',
#  'paul',
#  'ship',
#  'theater',
#  'falls',
#  'taking',
#  'extremely',
#  'living',
#  'cop',
#  'none',
#  'enjoy',
#  'hours',
#  'number',
#  'computer',
#  'leave',
#  'talk',
#  'premise',
#  'appears',
#  'god',
#  'co',
#  'particularly',
#  'taken',
#  'late',
#  'material',
#  'middle',
#  'among',
#  'leads',
#  'wild',
#  'attention',
#  'van',
#  'science',
#  'alone',
#  'tale',
#  'oh',
#  'power',
#  'art',
#  'poor',
#  'interest',
#  'future',
#  'meets',
#  'except',
#  'robin',
#  'seemed',
#  'word',
#  'guess',
#  'happy',
#  'released',
#  'told',
#  'expect',
#  'easy',
#  'office',
#  'usually',
#  'killed',
#  'attempts',
#  'aliens',
#  'planet',
#  'within',
#  'talent',
#  'call',
#  'forced',
#  'stuff',
#  'entertainment',
#  'history',
#  'die',
#  'chance',
#  'happen',
#  'viewer',
#  'success',
#  'whether',
#  'serious',
#  'cut',
#  'words',
#  'important',
#  'harry',
#  'william',
#  'across',
#  'quality',
#  'turned',
#  'battle',
#  'giving',
#  'wonderful',
#  'runs',
#  'features',
#  'light',
#  'return',
#  'obviously',
#  'basically',
#  'flick',
#  'needs',
#  'form',
#  'feels',
#  'parts',
#  'impressive',
#  'excellent',
#  'talking',
#  'easily',
#  'release',
#  'jones',
#  'surprise',
#  'slow',
#  'shots',
#  'williams',
#  'score',
#  'murphy',
#  'rock',
#  'surprisingly',
#  'girlfriend',
#  'brings',
#  'hilarious',
#  'television',
#  'brothers',
#  'straight',
#  'ago',
#  'crime',
#  'ways',
#  'recent',
#  'parents',
#  'somehow',
#  'apparently',
#  'deal',
#  'amazing',
#  'near',
#  'using',
#  'present',
#  'feeling',
#  'went',
#  'suspense',
#  'events',
#  'credits',
#  'local',
#  'minute',
#  'cool',
#  'effective',
#  'villain',
#  'crew',
#  'sequel',
#  'difficult',
#  'popular',
#  'personal',
#  'reality',
#  'dramatic',
#  'sexual',
#  'filmmakers',
#  'fast',
#  'bob',
#  'rich',
#  'questions',
#  'working',
#  'business',
#  'certain',
#  'latest',
#  'mission',
#  'somewhat',
#  'situation',
#  'company',
#  'leaves',
#  'ben',
#  'box',
#  'america',
#  'carter',
#  'uses',
#  'jim',
#  'smart',
#  'gone',
#  'general',
#  'romance',
#  'change',
#  'bunch',
#  'figure',
#  'means',
#  'type',
#  'red',
#  'blood',
#  'moving',
#  'absolutely',
#  'due',
#  'kid',
#  'scott',
#  '4',
#  'decides',
#  'starring',
#  'successful',
#  'b',
#  'beyond',
#  'low',
#  'came',
#  'annoying',
#  'million',
#  'remember',
#  'motion',
#  'martin',
#  'budget',
#  'drug',
#  'leaving',
#  'age',
#  'scary',
#  'similar',
#  'clear',
#  'party',
#  'giant',
#  'prison',
#  'follow',
#  'doubt',
#  'saying',
#  'move',
#  'presence',
#  'seriously',
#  'begin',
#  'complete',
#  'secret',
#  'message',
#  'anyway',
#  'eye',
#  'r',
#  'familiar',
#  'nature',
#  'mystery',
#  'studio',
#  'third',
#  'add',
#  'frank',
#  'agent',
#  'intelligent',
#  'huge',
#  'powerful',
#  'country',
#  'decent',
#  'chan',
#  'felt',
#  'project',
#  'water',
#  'writing',
#  'ex',
#  'trek',
#  'clever',
#  'brilliant',
#  'law',
#  'created',
#  'large',
#  'filled',
#  'predictable',
#  'towards',
#  'wedding',
#  'former',
#  'definitely',
#  'read',
#  'eddie',
#  'previous',
#  'animated',
#  'break',
#  'cinema',
#  'view',
#  'gun',
#  'mark',
#  'understand',
#  'pay',
#  'non',
#  'simon',
#  'visual',
#  'following',
#  'strange',
#  'unlike',
#  'fan',
#  'usual',
#  'realize',
#  'actress',
#  'create',
#  'follows',
#  'ryan',
#  'married',
#  'dream',
#  'escape',
#  'stories',
#  'inside',
#  'opens',
#  'wars',
#  'ones',
#  '5',
#  'learn',
#  'plan',
#  'overall',
#  'various',
#  'thinking',
#  'favorite',
#  'liked',
#  'solid',
#  'open',
#  'e',
#  'entirely',
#  'enjoyable',
#  'neither',
#  'subject',
#  'government',
#  'cold',
#  'stay',
#  'west',
#  'happened',
#  'richard',
#  'mess',
#  'merely',
#  'points',
#  'impossible',
#  'ten',
#  'exciting',
#  'spend',
#  'english',
#  'chase',
#  'class',
#  'potential',
#  'particular',
#  'ideas',
#  'heard',
#  'appear',
#  'modern',
#  'likely',
#  'state',
#  'bruce',
#  'offers',
#  'wanted',
#  'expected',
#  'audiences',
#  'brought',
#  'soundtrack',
#  'biggest',
#  'joke',
#  'sam',
#  'u',
#  'silly',
#  'keeps',
#  'memorable',
#  'truman',
#  'gave',
#  'hands',
#  'steve',
#  'sweet',
#  'focus',
#  'screenwriter',
#  'viewers',
#  'took',
#  'allen',
#  'free',
#  'cameron',
#  'perfectly',
#  'minor',
#  'army',
#  'trouble',
#  'totally',
#  'effect',
#  'teen',
#  'club',
#  'female',
#  'talented',
#  'park',
#  'fire',
#  'effort',
#  'bill',
#  'constantly',
#  'control',
#  'situations',
#  'impact',
#  'cinematography',
#  'cannot',
#  'ask',
#  'showing',
#  'immediately',
#  'stone',
#  'fails',
#  'l',
#  'slightly',
#  'rating',
#  'killing',
#  'force',
#  'sean',
#  'wait',
#  'woody',
#  'rated',
#  'amusing',
#  'mary',
#  'air',
#  '8',
#  'political',
#  'members',
#  'tim',
#  'nick',
#  'stand',
#  'actual',
#  'theme',
#  'credit',
#  'grace',
#  'otherwise',
#  'max',
#  'dumb',
#  'lots',
#  'waste',
#  'tone',
#  'truth',
#  'humans',
#  'purpose',
#  'choice',
#  'typical',
#  'animation',
#  'willis',
#  'complex',
#  'key',
#  'society',
#  'thinks',
#  'tarzan',
#  'sister',
#  'violent',
#  'telling',
#  'sit',
#  'ultimately',
#  'shown',
#  'songs',
#  'x',
#  'road',
#  'puts',
#  'song',
#  'fear',
#  'setting',
#  'element',
#  'sees',
#  'ability',
#  'college',
#  'six',
#  'possibly',
#  'famous',
#  'somewhere',
#  'atmosphere',
#  'today',
#  'subtle',
#  'indeed',
#  'dreams',
#  'critics',
#  'steven',
#  'tension',
#  'whatever',
#  'cheap',
#  'fairly',
#  'beauty',
#  'convincing',
#  'flat',
#  'cinematic',
#  'fi',
#  'seven',
#  'longer',
#  'clearly',
#  'jackson',
#  'disaster',
#  'heavy',
#  'ridiculous',
#  'british',
#  'sounds',
#  'earlier',
#  'sci',
#  'depth',
#  'front',
#  'musical',
#  'plenty',
#  'images',
#  'chemistry',
#  'recently',
#  'etc',
#  'basic',
#  'bond',
#  'spent',
#  'amount',
#  'outside',
#  'okay',
#  'tough',
#  'highly',
#  'list',
#  'island',
#  'greatest',
#  'quick',
#  'seemingly',
#  'moves',
#  'considering',
#  'queen',
#  'wish',
#  'climax',
#  'wrote',
#  'hate',
#  'provides',
#  'cute',
#  'language',
#  'looked',
#  'ii',
#  'background',
#  'ride',
#  'occasionally',
#  'century',
#  'private',
#  'remains',
#  'boss',
#  'hong',
#  'detective',
#  'approach',
#  'subplot',
#  'mike',
#  'baby',
#  'french',
#  'trailer',
#  'suddenly',
#  'street',
#  'imagine',
#  'boys',
#  'double',
#  'interested',
#  'slowly',
#  'reasons',
#  'decide',
#  'average',
#  'leading',
#  'awful',
#  'concept',
#  'hold',
#  'hear',
#  'terrible',
#  'leader',
#  'hot',
#  'alive',
#  'powers',
#  'writers',
#  'victim',
#  'directors',
#  'tarantino',
#  'asks',
#  'carry',
#  'blue',
#  'energy',
#  'led',
#  'provide',
#  'opportunity',
#  'male',
#  'brown',
#  'proves',
#  'miss',
#  'titanic',
#  'casting',
#  'consider',
#  ...]

# %%
def get_features(document):
    words = set(document)
    features = {}
    for w in feature_words:
        features[w] = (w in words)
    return features

# %%
training_data = [(get_features(a), b) for (a, b) in training_documents]

# %%
testing_data = [(get_features(a), b) for (a, b) in testing_documents]

# %%
classifier = nltk.NaiveBayesClassifier.train(training_data)

# %%
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#              outstanding = True              pos : neg    =     21.7 : 1.0
#                   castle = True              pos : neg    =     11.1 : 1.0
#                   alicia = True              neg : pos    =     10.9 : 1.0
#                    anger = True              pos : neg    =      8.3 : 1.0
#                   prinze = True              neg : pos    =      8.2 : 1.0
#                    waste = True              neg : pos    =      7.9 : 1.0
#                    mulan = True              pos : neg    =      7.8 : 1.0
#                      era = True              pos : neg    =      7.6 : 1.0
#                    inept = True              neg : pos    =      7.6 : 1.0
#               schumacher = True              neg : pos    =      7.6 : 1.0

# %%
nltk.classify.accuracy(classifier, testing_data)
# Out:
# 0.804

# %%
from nltk.classify.scikitlearn import SklearnClassifier
from  sklearn.svm import SVC

# %%
classifier_sklearn = SklearnClassifier(SVC())
classifier_sklearn.train(training_data)
# Out:
# <SklearnClassifier(SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))>

# %%
nltk.classify.accuracy(classifier_sklearn, testing_data)
# Out:
# 0.754

# %%
pos_doc = pos_tag(all_words)

# %%
pos_doc
# Out:
# [('highly', 'RB'),
#  ('built', 'VBN'),
#  ('truman', 'NN'),
#  ('show', 'NN'),
#  ('reviews', 'VBZ'),
#  ('boasting', 'VBG'),
#  ('decade', 'NN'),
#  ('breakthrough', 'IN'),
#  ('leading', 'VBG'),
#  ('letdown', 'JJ'),
#  ('doubt', 'NN'),
#  ('seems', 'VBZ'),
#  ('critical', 'JJ'),
#  ('acclaim', 'NN'),
#  ('makes', 'VBZ'),
#  ('think', 'VBP'),
#  ('going', 'VBG'),
#  ('ride', 'NN'),
#  ('life', 'NN'),
#  ('end', 'NN'),
#  ('changed', 'VBD'),
#  ('side', 'JJ'),
#  ('come', 'JJ'),
#  ('theater', 'NN'),
#  ('going', 'VBG'),
#  ('eh', 'JJ'),
#  ('fuss', 'NNS'),
#  ('naturally', 'RB'),
#  ('truman', 'VBP'),
#  ('show', 'NN'),
#  ('building', 'NN'),
#  ('going', 'VBG'),
#  ('dissapointment', 'NN'),
#  ('convinced', 'VBD'),
#  ('nestled', 'VBN'),
#  ('uncomfortable', 'JJ'),
#  ('theater', 'NN'),
#  ('chair', 'NN'),
#  ('actually', 'RB'),
#  ('try', 'VB'),
#  ('enjoy', 'JJ'),
#  ('let', 'VB'),
#  ('tell', 'VB'),
#  ('impossibilty', 'VB'),
#  ('truman', 'NN'),
#  ('show', 'NN'),
#  ('truly', 'RB'),
#  ('decade', 'NN'),
#  ('breakthrough', 'IN'),
#  ('come', 'NN'),
#  ('changed', 'VBD'),
#  ('side', 'NN'),
#  ('comes', 'VBZ'),
#  ('around', 'RP'),
#  ('lifetime', 'JJ'),
#  ('find', 'VB'),
#  ('feeling', 'NN'),
#  ('everything', 'NN'),
#  ('character', 'NN'),
#  ('feeling', 'VBG'),
#  ('friends', 'NNS'),
#  ('jim', 'NN'),
#  ('carrey', 'NN'),
#  ('shows', 'NNS'),
#  ('need', 'VBP'),
#  ('talk', 'NN'),
#  ('butt', 'NN'),
#  ('entertain', 'VBP'),
#  ('us', 'PRP'),
#  ('dramatic', 'JJ'),
#  ('hollywood', 'NN'),
#  ('leading', 'VBG'),
#  ('men', 'NNS'),
#  ('difficult', 'JJ'),
#  ('premise', 'NN'),
#  ('tackle', 'NN'),
#  ('trying', 'VBG'),
#  ('set', 'VBD'),
#  ('us', 'PRP'),
#  ('thirty', 'JJ'),
#  ('years', 'NNS'),
#  ('truman', 'VBP'),
#  ('show', 'VBP'),
#  ('run', 'VB'),
#  ('tackle', 'RB'),
#  ('perfectly', 'RB'),
#  ('flashbacks', 'VBZ'),
#  ('actually', 'RB'),
#  ('flashbacks', 'JJ'),
#  ('television', 'NN'),
#  ('show', 'NN'),
#  ('get', 'VBP'),
#  ('sense', 'NN'),
#  ('viewing', 'VBG'),
#  ('real', 'JJ'),
#  ('prime', 'JJ'),
#  ('time', 'NN'),
#  ('hit', 'VB'),
#  ('way', 'NN'),
#  ('camera', 'NN'),
#  ('constantly', 'RB'),
#  ('takes', 'VBZ'),
#  ('forms', 'NNS'),
#  ('would', 'MD'),
#  ('real', 'JJ'),
#  ('truman', 'NN'),
#  ('show', 'NN'),
#  ('clever', 'RB'),
#  ('well', 'RB'),
#  ('done', 'VBN'),
#  ('people', 'NNS'),
#  ('rejoice', 'VBP'),
#  ('first', 'JJ'),
#  ('oscar', 'NN'),
#  ('worthy', 'JJ'),
#  ('year', 'NN'),
#  ('last', 'JJ'),
#  ('five', 'CD'),
#  ('years', 'NNS'),
#  ('since', 'IN'),
#  ('schindler', 'NN'),
#  ('list', 'NN'),
#  ('captured', 'VBD'),
#  ('human', 'JJ'),
#  ('spirit', 'NN'),
#  ('true', 'JJ'),
#  ('despair', 'NN'),
#  ('well', 'RB'),
#  ('classic', 'JJ'),
#  ('making', 'VBG'),
#  ('borrow', 'JJ'),
#  ('line', 'NN'),
#  ('esquire', 'NN'),
#  ('review', 'NN'),
#  ('stars', 'NNS'),
#  ('jim', 'VBP'),
#  ('carrey', 'JJ'),
#  ('nothing', 'NN'),
#  ('career', 'NN'),
#  ('date', 'NN'),
#  ('nothing', 'NN'),
#  ('future', 'JJ'),
#  ('ever', 'RB'),
#  ('able', 'JJ'),
#  ('top', 'JJ'),
#  ('role', 'NN'),
#  ('truman', 'NN'),
#  ('burbank', 'VBD'),
#  ('mark', 'NN'),
#  ('word', 'NN'),
#  ('said', 'VBD'),
#  ('lifetime', 'JJ'),
#  ('role', 'NN'),
#  ('calibre', 'NN'),
#  ('forget', 'VB'),
#  ('special', 'JJ'),
#  ('effect', 'NN'),
#  ('ladden', 'JJ'),
#  ('summer', 'NN'),
#  ('fodder', 'NN'),
#  ('drop', 'NN'),
#  ('romantic', 'JJ'),
#  ('comedies', 'NNS'),
#  ('trash', 'VBP'),
#  ('toss', 'IN'),
#  ('thrillers', 'NNS'),
#  ('teen', 'JJ'),
#  ('flicks', 'NNS'),
#  ('pile', 'VBP'),
#  ('need', 'VBP'),
#  ('nothing', 'NN'),
#  ('truman', 'NN'),
#  ('show', 'NN'),
#  ('carry', 'VBP'),
#  ('summer', 'NN'),
#  ('matter', 'NN'),
#  ('year', 'NN'),
#  ('oh', 'RB'),
#  ('case', 'NN'),
#  ('see', 'VB'),
#  ('good', 'JJ'),
#  ('afternoon', 'NN'),
#  ('good', 'JJ'),
#  ('evening', 'NN'),
#  ('goodnight', 'NN'),
#  ('susan', 'JJ'),
#  ('granger', 'NN'),
#  ('review', 'NN'),
#  ('songcatcher', 'NN'),
#  ('midst', 'NN'),
#  ('summer', 'NN'),
#  ('fare', 'NN'),
#  ('dinos', 'NN'),
#  ('revisited', 'VBD'),
#  ('romantic', 'JJ'),
#  ('fiascoes', 'NNS'),
#  ('thoughtful', 'JJ'),
#  ('movies', 'NNS'),
#  ('appalachian', 'JJ'),
#  ('period', 'NN'),
#  ('drama', 'NN'),
#  ('one', 'CD'),
#  ('oscar', 'NN'),
#  ('nominee', 'JJ'),
#  ('janet', 'NN'),
#  ('mcteer', 'NN'),
#  ('tumbleweeds', 'NNS'),
#  ('stars', 'VBZ'),
#  ('dr', 'JJ'),
#  ('lily', 'RB'),
#  ('penleric', 'JJ'),
#  ('accomplished', 'VBD'),
#  ('musicologist', 'NN'),
#  ('back', 'RB'),
#  ('pre', 'JJ'),
#  ('feminist', 'NN'),
#  ('era', 'NN'),
#  ('refused', 'VBD'),
#  ('full', 'JJ'),
#  ('professorship', 'NN'),
#  ('university', 'NN'),
#  ('determined', 'VBN'),
#  ('prove', 'IN'),
#  ('worth', 'JJ'),
#  ('ventures', 'NNS'),
#  ('deep', 'VBP'),
#  ('rugged', 'VBN'),
#  ('mountains', 'NNS'),
#  ('north', 'JJ'),
#  ('carolina', 'JJ'),
#  ('younger', 'JJR'),
#  ('sister', 'NN'),
#  ('elna', 'NN'),
#  ('jane', 'NN'),
#  ('adams', 'NNS'),
#  ('runs', 'VBZ'),
#  ('school', 'NN'),
#  ('bear', 'NN'),
#  ('creek', 'NN'),
#  ('discovers', 'NNS'),
#  ('treasure', 'VBP'),
#  ('trove', 'IN'),
#  ('traditional', 'JJ'),
#  ('scots', 'NNS'),
#  ('irish', 'JJ'),
#  ('english', 'JJ'),
#  ('folk', 'NN'),
#  ('ballads', 'NNS'),
#  ('given', 'VBN'),
#  ('unique', 'JJ'),
#  ('interpretation', 'NN'),
#  ('insular', 'JJ'),
#  ('locals', 'NNS'),
#  ('excited', 'VBD'),
#  ('sends', 'NNS'),
#  ('recording', 'VBG'),
#  ('equipment', 'NN'),
#  ('persuades', 'NNS'),
#  ('vinie', 'VBP'),
#  ('butler', 'NN'),
#  ('pat', 'NN'),
#  ('carroll', 'NN'),
#  ('self', 'NN'),
#  ('sustaining', 'VBG'),
#  ('mountain', 'NN'),
#  ('folk', 'NN'),
#  ('share', 'NN'),
#  ('musical', 'JJ'),
#  ('heritage', 'NN'),
#  ('edison', 'NN'),
#  ('phonograph', 'NN'),
#  ('cylinders', 'NNS'),
#  ('music', 'NN'),
#  ('puts', 'VBZ'),
#  ('much', 'JJ'),
#  ('part', 'NN'),
#  ('life', 'NN'),
#  ('air', 'NN'),
#  ('breathe', 'NN'),
#  ('main', 'JJ'),
#  ('thrust', 'JJ'),
#  ('writer', 'NN'),
#  ('director', 'NN'),
#  ('maggie', 'VBD'),
#  ('greenwald', 'NNS'),
#  ('occasionally', 'RB'),
#  ('uneven', 'JJ'),
#  ('culture', 'NN'),
#  ('clash', 'NN'),
#  ('story', 'NN'),
#  ('loosely', 'RB'),
#  ('based', 'VBN'),
#  ('olive', 'JJ'),
#  ('dame', 'NN'),
#  ('campbell', 'NN'),
#  ('foray', 'NN'),
#  ('blue', 'JJ'),
#  ('ridge', 'NN'),
#  ('mountains', 'NNS'),
#  ('1908', 'CD'),
#  ('also', 'RB'),
#  ('melodramatic', 'JJ'),
#  ('romantic', 'JJ'),
#  ('spice', 'NN'),
#  ('ornery', 'NN'),
#  ('bearded', 'VBD'),
#  ('banjo', 'NN'),
#  ('picking', 'VBG'),
#  ('aidan', 'JJ'),
#  ('quinn', 'NN'),
#  ('falls', 'VBZ'),
#  ('statuesque', 'JJ'),
#  ('passionate', 'NN'),
#  ('songcatcher', 'NN'),
#  ('elna', 'NN'),
#  ('secretly', 'RB'),
#  ('engages', 'VBZ'),
#  ('lesbian', 'JJ'),
#  ('relationship', 'NN'),
#  ('colleague', 'NN'),
#  ('e', 'NN'),
#  ('katherine', 'NN'),
#  ('kerr', 'NN'),
#  ('ready', 'JJ'),
#  ('buy', 'VB'),
#  ('soulful', 'JJ'),
#  ('soundtrack', 'NN'),
#  ('vocalists', 'NNS'),
#  ('like', 'IN'),
#  ('emmylou', 'JJ'),
#  ('harris', 'NN'),
#  ('iris', 'JJ'),
#  ('dement', 'NN'),
#  ('taj', 'NN'),
#  ('mahal', 'NN'),
#  ('young', 'JJ'),
#  ('opera', 'NN'),
#  ('star', 'NN'),
#  ('emmy', 'JJ'),
#  ('rossum', 'NN'),
#  ('plays', 'NNS'),
#  ('pivotal', 'JJ'),
#  ('role', 'NN'),
#  ('mcteer', 'NN'),
#  ('wide', 'JJ'),
#  ('eyed', 'VBD'),
#  ('prot', 'NN'),
#  ('g', 'NN'),
#  ('rated', 'VBD'),
#  ('pg', 'JJ'),
#  ('13', 'CD'),
#  ('intense', 'JJ'),
#  ('scene', 'NN'),
#  ('primitive', 'JJ'),
#  ('childbirth', 'NN'),
#  ('granger', 'NN'),
#  ('gauge', 'VBD'),
#  ('1', 'CD'),
#  ('10', 'CD'),
#  ('songcatcher', 'NN'),
#  ('intelligent', 'NN'),
#  ('extraordinary', 'JJ'),
#  ('8', 'CD'),
#  ('transported', 'VBN'),
#  ('transcendent', 'JJ'),
#  ('power', 'NN'),
#  ('song', 'NN'),
#  ('along', 'IN'),
#  ('carreer', 'NN'),
#  ('mel', 'NN'),
#  ('gibson', 'NN'),
#  ('collected', 'VBD'),
#  ('several', 'JJ'),
#  ('successes', 'NNS'),
#  ('economic', 'JJ'),
#  ('point', 'NN'),
#  ('view', 'NN'),
#  ('also', 'RB'),
#  ('artistic', 'JJ'),
#  ('point', 'NN'),
#  ('view', 'NN'),
#  ('think', 'VBP'),
#  ('one', 'CD'),
#  ('could', 'MD'),
#  ('guess', 'VB'),
#  ('skills', 'NNS'),
#  ('abilities', 'NNS'),
#  ('disclosed', 'VBD'),
#  ('braveheart', 'RB'),
#  ('australian', 'JJ'),
#  ('actor', 'NN'),
#  ('decided', 'VBD'),
#  ('produce', 'NN'),
#  ('direct', 'JJ'),
#  ('sir', 'NN'),
#  ('william', 'NN'),
#  ('wallace', 'NN'),
#  ('popular', 'JJ'),
#  ('scotch', 'NN'),
#  ('hero', 'NN'),
#  ('13th', 'JJ'),
#  ('century', 'NN'),
#  ('would', 'MD'),
#  ('also', 'RB'),
#  ('perform', 'VB'),
#  ('principal', 'JJ'),
#  ('role', 'NN'),
#  ('accepting', 'VBG'),
#  ('huge', 'JJ'),
#  ('challenge', 'NN'),
#  ('mel', 'NN'),
#  ('gibson', 'NN'),
#  ('run', 'NN'),
#  ('risk', 'NN'),
#  ('stain', 'VBP'),
#  ('work', 'NN'),
#  ('years', 'NNS'),
#  ('suppoosed', 'JJ'),
#  ('failure', 'NN'),
#  ('see', 'VB'),
#  ('recognized', 'VBN'),
#  ('everyone', 'NN'),
#  ('potentialities', 'VBZ'),
#  ('way', 'NN'),
#  ('consolidate', 'JJ'),
#  ('position', 'NN'),
#  ('hollywood', 'NN'),
#  ('definitely', 'RB'),
#  ('enormous', 'JJ'),
#  ('risk', 'NN'),
#  ('sure', 'JJ'),
#  ('mel', 'VBZ'),
#  ('knew', 'FW'),
#  ('exactly', 'RB'),
#  ('well', 'RB'),
#  ('going', 'VBG'),
#  ('face', 'NN'),
#  ('braveheart', 'NN'),
#  ('fact', 'NN'),
#  ('magnificent', 'JJ'),
#  ('magisterial', 'JJ'),
#  ('three', 'CD'),
#  ('hours', 'NNS'),
#  ('completely', 'RB'),
#  ('absorbed', 'VBD'),
#  ('narrative', 'JJ'),
#  ('rhyitm', 'NN'),
#  ('never', 'RB'),
#  ('gives', 'VBZ'),
#  ('place', 'NN'),
#  ('single', 'JJ'),
#  ('moment', 'NN'),
#  ('monotony', 'NN'),
#  ('uninterest', 'JJS'),
#  ('william', 'JJ'),
#  ('wallace', 'NN'),
#  ('story', 'NN'),
#  ('story', 'NN'),
#  ('many', 'JJ'),
#  ('others', 'NNS'),
#  ('brave', 'VBP'),
#  ('liberty', 'JJ'),
#  ('defenders', 'NNS'),
#  ('fought', 'VBN'),
#  ('gave', 'VBD'),
#  ('life', 'NN'),
#  ('essential', 'JJ'),
#  ('value', 'NN'),
#  ('along', 'IN'),
#  ('centuries', 'NNS'),
#  ('seeing', 'VBG'),
#  ('people', 'NNS'),
#  ('victims', 'NNS'),
#  ('injustices', 'NNS'),
#  ('violent', 'JJ'),
#  ('repression', 'NN'),
#  ('william', 'VBD'),
#  ('wallace', 'NN'),
#  ('dares', 'NNS'),
#  ('face', 'VBP'),
#  ('powerful', 'JJ'),
#  ('edward', 'RB'),
#  ('king', 'VBG'),
#  ('england', 'NNP'),
#  ('war', 'NN'),
#  ('autonomy', 'NN'),
#  ('scotland', 'NN'),
#  ('victories', 'NNS'),
#  ('succeed', 'VB'),
#  ('number', 'NN'),
#  ('fighters', 'NNS'),
#  ('wallace', 'VBP'),
#  ('goes', 'VBZ'),
#  ('growing', 'VBG'),
#  ('courage', 'NN'),
#  ('inteligence', 'NN'),
#  ('admired', 'VBD'),
#  ('everyone', 'NN'),
#  ('including', 'VBG'),
#  ('princess', 'JJ'),
#  ('isabelle', 'NN'),
#  ('wales', 'NNS'),
#  ('wife', 'NN'),
#  ('edward', 'VBP'),
#  ('son', 'NN'),
#  ('however', 'RB'),
#  ('william', 'JJ'),
#  ('wallace', 'NN'),
#  ('also', 'RB'),
#  ('surrounded', 'VBD'),
#  ('enemies', 'NNS'),
#  ('closer', 'RBR'),
#  ('thought', 'JJ'),
#  ('braveheart', 'NN'),
#  ('may', 'MD'),
#  ('historically', 'RB'),
#  ('corrected', 'VBN'),
#  ('nature', 'NN'),
#  ('message', 'NN'),
#  ('make', 'VBP'),
#  ('us', 'PRP'),
#  ('think', 'VB'),
#  ('importance', 'NN'),
#  ('give', 'JJ'),
#  ('liberty', 'NN'),
#  ('nowadays', 'NNS'),
#  ('mel', 'VBP'),
#  ('gibson', 'JJ'),
#  ('directs', 'NNS'),
#  ('lot', 'NN'),
#  ('brilliancy', 'NN'),
#  ('brilliant', 'JJ'),
#  ('cast', 'NN'),
#  ('patrick', 'NN'),
#  ('mcgoohan', 'NN'),
#  ('nice', 'JJ'),
#  ('performance', 'NN'),
#  ('edward', 'NN'),
#  ('king', 'VBG'),
#  ('longshank', 'JJ'),
#  ('scene', 'NN'),
#  ('waits', 'NNS'),
#  ('death', 'NN'),
#  ('loses', 'VBZ'),
#  ('voice', 'NN'),
#  ('really', 'RB'),
#  ('good', 'JJ'),
#  ('sophie', 'NN'),
#  ('marceau', 'NN'),
#  ('princess', 'NN'),
#  ('isabelle', 'NN'),
#  ('along', 'IN'),
#  ('fifteen', 'JJ'),
#  ('minutes', 'NNS'),
#  ('performance', 'NN'),
#  ('mel', 'NN'),
#  ('gibson', 'NN'),
#  ('gave', 'VBD'),
#  ('minutes', 'NNS'),
#  ('special', 'JJ'),
#  ('treatment', 'NN'),
#  ('princess', 'NN'),
#  ('isabelle', 'NN'),
#  ('soon', 'RB'),
#  ('becomes', 'VBZ'),
#  ('one', 'CD'),
#  ('major', 'JJ'),
#  ('characters', 'NNS'),
#  ('braveheart', 'VBP'),
#  ('also', 'RB'),
#  ('liked', 'VBN'),
#  ('performances', 'NNS'),
#  ('angus', 'JJ'),
#  ('macfadyen', 'NN'),
#  ('robert', 'NN'),
#  ('bruce', 'NN'),
#  ('course', 'NN'),
#  ('mel', 'NN'),
#  ('gibson', 'NN'),
#  ('william', 'NN'),
#  ('wallace', 'NN'),
#  ('however', 'RB'),
#  ('think', 'VBP'),
#  ('time', 'NN'),
#  ('mel', 'NN'),
#  ('gibson', 'NN'),
#  ('work', 'NN'),
#  ('director', 'NN'),
#  ('much', 'JJ'),
#  ('better', 'JJR'),
#  ('work', 'NN'),
#  ('actor', 'NN'),
#  ('excellent', 'JJ'),
#  ('music', 'NN'),
#  ('composed', 'VBD'),
#  ('james', 'NNS'),
#  ('horner', 'VBP'),
#  ('another', 'DT'),
#  ('thing', 'NN'),
#  ('helps', 'VBZ'),
#  ('braveheart', 'VB'),
#  ('success', 'NN'),
#  ('really', 'RB'),
#  ('join', 'JJ'),
#  ('music', 'NN'),
#  ('beautiful', 'JJ'),
#  ('scotch', 'NN'),
#  ('landscapes', 'NNS'),
#  ('view', 'VBP'),
#  ('camera', 'NN'),
#  ('john', 'NN'),
#  ('toll', 'NN'),
#  ('realize', 'VBP'),
#  ('beauty', 'NN'),
#  ('braveheart', 'JJ'),
#  ('opinion', 'NN'),
#  ('one', 'CD'),
#  ('best', 'JJS'),
#  ('movies', 'NNS'),
#  ('1995', 'CD'),
#  ('heard', 'NN'),
#  ('people', 'NNS'),
#  ('saying', 'VBG'),
#  ('mel', 'JJ'),
#  ('gibson', 'NN'),
#  ('gonna', 'VBD'),
#  ('new', 'JJ'),
#  ('david', 'JJ'),
#  ('lean', 'JJ'),
#  ('let', 'NN'),
#  ('see', 'VB'),
#  ('braveheart', 'JJ'),
#  ('equalizes', 'VBZ'),
#  ('6', 'CD'),
#  ('oscars', 'NNS'),
#  ('lawrence', 'RB'),
#  ('arabia', 'VBP'),
#  ('easy', 'JJ'),
#  ('gonna', 'NN'),
#  ('one', 'CD'),
#  ('challenge', 'NN'),
#  ('mel', 'NN'),
#  ('gibson', 'NN'),
#  ('one', 'CD'),
#  ('days', 'NNS'),
#  ('make', 'VBP'),
#  ('good', 'JJ'),
#  ('promise', 'NN'),
#  ('never', 'RB'),
#  ('rent', 'VBD'),
#  ('another', 'DT'),
#  ('abel', 'NN'),
#  ('ferrara', 'NN'),
#  ('king', 'VBG'),
#  ('new', 'JJ'),
#  ('york', 'NN'),
#  ('body', 'NN'),
#  ('snatchers', 'NNS'),
#  ('notwithstanding', 'VBG'),
#  ('bad', 'JJ'),
#  ('lieutenant', 'JJ'),
#  ('fit', 'NN'),
#  ('single', 'JJ'),
#  ('emotive', 'JJ'),
#  ('viewing', 'VBG'),
#  ('exploitation', 'NN'),
#  ('flicks', 'NNS'),
#  ('fallen', 'VBN'),
#  ('rut', 'VBP'),
#  ('hoary', 'JJ'),
#  ('art', 'NN'),
#  ('house', 'NN'),
#  ('trappings', 'NNS'),
#  ('perfume', 'VBP'),
#  ('drenched', 'VBN'),
#  ('coke', 'NN'),
#  ('addled', 'VBD'),
#  ('visit', 'NN'),
#  ('seedy', 'NN'),
#  ('pornography', 'NN'),
#  ('shop', 'NN'),
#  ('beautiful', 'JJ'),
#  ('models', 'NNS'),
#  ('hookers', 'NNS'),
#  ('courtesans', 'VBP'),
#  ('usher', 'JJ'),
#  ('silk', 'NN'),
#  ('curtains', 'NNS'),
#  ('ferrara', 'VBP'),
#  ('consistently', 'RB'),
#  ('smart', 'JJ'),
#  ('move', 'NN'),
#  ('casting', 'VBG'),
#  ('christopher', 'NN'),
#  ('walken', 'NN'),
#  ('since', 'IN'),
#  ('walken', 'NNS'),
#  ('make', 'VBP'),
#  ('good', 'JJ'),
#  ('great', 'JJ'),
#  ('loathsome', 'JJ'),
#  ('durable', 'JJ'),
#  ('whenever', 'NN'),
#  ('onscreen', 'VBD'),
#  ('8', 'CD'),
#  ('minute', 'JJ'),
#  ('scene', 'NN'),
#  ('addiction', 'NN'),
#  ('saving', 'VBG'),
#  ('grace', 'NN'),
#  ('otherwise', 'RB'),
#  ('abysmal', 'JJ'),
#  ('unwatchable', 'JJ'),
#  ('pretentious', 'JJ'),
#  ('failure', 'NN'),
#  ('starts', 'VBZ'),
#  ('talking', 'VBG'),
#  ('vampiric', 'JJ'),
#  ('bowel', 'NN'),
#  ('movements', 'NNS'),
#  ('questions', 'NNS'),
#  ('whether', 'IN'),
#  ('lili', 'NN'),
#  ('taylor', 'NN'),
#  ('ever', 'RB'),
#  ('read', 'VBD'),
#  ('naked', 'JJ'),
#  ('lunch', 'NN'),
#  ('much', 'RB'),
#  ('needed', 'VBN'),
#  ('dose', 'JJ'),
#  ('humor', 'NN'),
#  ('otherwise', 'RB'),
#  ('terminally', 'RB'),
#  ('unfunny', 'JJ'),
#  ('affair', 'NN'),
#  ('know', 'VBP'),
#  ('gothic', 'JJ'),
#  ('club', 'NN'),
#  ('kids', 'NNS'),
#  ('cool', 'VBP'),
#  ('smile', 'JJ'),
#  ('let', 'NN'),
#  ('know', 'VB'),
#  ('actually', 'RB'),
#  ('fun', 'JJ'),
#  ('addiction', 'NN'),
#  ('walken', 'NNS'),
#  ('sadly', 'RB'),
#  ('appear', 'VBP'),
#  ('blackout', 'IN'),
#  ('central', 'JJ'),
#  ('role', 'NN'),
#  ('matty', 'NN'),
#  ('junkie', 'NN'),
#  ('star', 'NN'),
#  ('whose', 'WP$'),
#  ('lightning', 'NN'),
#  ('paced', 'VBD'),
#  ('hollywood', 'JJ'),
#  ('life', 'NN'),
#  ('among', 'IN'),
#  ('beautiful', 'JJ'),
#  ('people', 'NNS'),
#  ('inevitably', 'RB'),
#  ('leading', 'VBG'),
#  ('destruction', 'NN'),
#  ('played', 'VBD'),
#  ('matthew', 'JJ'),
#  ('modine', 'NN'),
#  ('takes', 'VBZ'),
#  ('get', 'VBP'),
#  ('cutthroat', 'JJ'),
#  ('island', 'RB'),
#  ('much', 'RB'),
#  ('like', 'IN'),
#  ('protagonists', 'NNS'),
#  ('michelangelo', 'VBP'),
#  ('antonioni', 'RB'),
#  ('terminally', 'RB'),
#  ('bored', 'JJ'),
#  ('cultural', 'JJ'),
#  ('elite', 'NN'),
#  ('matty', 'NNS'),
#  ('involved', 'VBN'),
#  ('bitter', 'JJ'),
#  ('pill', 'NN'),
#  ('relationship', 'NN'),
#  ('high', 'JJ'),
#  ('fashioned', 'VBN'),
#  ('model', 'NN'),
#  ('annie', 'NN'),
#  ('least', 'JJS'),
#  ('think', 'VBP'),
#  ('model', 'FW'),
#  ('matty', 'FW'),
#  ('lady', 'JJ'),
#  ('played', 'VBN'),
#  ('french', 'JJ'),
#  ('actress', 'NN'),
#  ('b', 'NN'),
#  ('atrice', 'NN'),
#  ('dalle', 'NN'),
#  ('arrested', 'VBN'),
#  ('twice', 'RB'),
#  ('cocaine', 'JJ'),
#  ('possession', 'NN'),
#  ('filming', 'VBG'),
#  ('blackout', 'NN'),
#  ('needed', 'VBN'),
#  ('know', 'VBP'),
#  ('lends', 'VBZ'),
#  ('credence', 'NN'),
#  ('idea', 'NN'),
#  ('ferrara', 'NN'),
#  ('entire', 'JJ'),
#  ('oeuvre', 'NN'),
#  ('filmed', 'VBD'),
#  ('fucking', 'VBG'),
#  ('blackout', 'IN'),
#  ('kidding', 'VBG'),
#  ('requiem', 'JJ'),
#  ('dream', 'NN'),
#  ('nothing', 'NN'),
#  ('junkie', 'NN'),
#  ('presentations', 'NNS'),
#  ('seen', 'VBN'),
#  ('ferrara', 'JJ'),
#  ('movies', 'NNS'),
#  ('controversial', 'JJ'),
#  ('urban', 'JJ'),
#  ('lifestyle', 'JJ'),
#  ('matty', 'NN'),
#  ('annie', 'NN'),
#  ('struggle', 'NN'),
#  ('decision', 'NN'),
#  ('abortion', 'NN'),
#  ('without', 'IN'),
#  ('consulting', 'VBG'),
#  ('doubt', 'NN'),
#  ('chasing', 'VBG'),
#  ('dragon', 'NN'),
#  ('despair', 'NN'),
#  ('matty', 'JJ'),
#  ('indulges', 'VBZ'),
#  ('chemical', 'NN'),
#  ('induced', 'VBD'),
#  ('weekend', 'NN'),
#  ('debauchery', 'NN'),
#  ('tooling', 'VBG'),
#  ('around', 'IN'),
#  ('streets', 'NNS'),
#  ('miami', 'VBP'),
#  ('video', 'NN'),
#  ('filmmaker', 'NN'),
#  ('mickey', 'NN'),
#  ('wayne', 'NN'),
#  ('dennis', 'NN'),
#  ('hopper', 'NN'),
#  ('full', 'JJ'),
#  ('dirty', 'NN'),
#  ('ol', 'NN'),
#  ('man', 'NN'),
#  ('mold', 'VBD'),
#  ('smacking', 'JJ'),
#  ('models', 'NNS'),
#  ('ass', 'VBP'),
#  ('telling', 'VBG'),
#  ('spread', 'NN'),
#  ('legs', 'NNS'),
#  ('wider', 'VBP'),
#  ('toward', 'IN'),
#  ('end', 'NN'),
#  ('night', 'NN'),
#  ('pick', 'NN'),
#  ('teenage', 'NN'),
#  ('waitress', 'NN'),
#  ('also', 'RB'),
#  ('named', 'VBD'),
#  ('annie', 'JJ'),
#  ('sarah', 'NN'),
#  ('lassez', 'JJ'),
#  ('start', 'NN'),
#  ('shooting', 'VBG'),
#  ('hastily', 'RB'),
#  ('improvised', 'VBN'),
#  ('sexual', 'JJ'),
#  ('scene', 'NN'),
#  ('matty', 'NNS'),
#  ('thankfully', 'RB'),
#  ('blacks', 'NNS'),
#  ('something', 'NN'),
#  ('happened', 'VBD'),
#  ('night', 'NN'),
#  ('haunts', 'NNS'),
#  ('throughout', 'IN'),
#  ('rest', 'VBP'),
#  ('exactly', 'RB'),
#  ('think', 'VBP'),
#  ('suffice', 'NNS'),
#  ('say', 'VBP'),
#  ('confusion', 'NN'),
#  ('whether', 'IN'),
#  ('killed', 'VBN'),
#  ('annie', 'RB'),
#  ('one', 'CD'),
#  ('annie', 'NN'),
#  ('two', 'CD'),
#  ('anyone', 'NN'),
#  ('blackout', 'NN'),
#  ('typical', 'JJ'),
#  ('ferrara', 'NN'),
#  ('plot', 'NN'),
#  ('speak', 'JJ'),
#  ('plenty', 'NN'),
#  ('raunch', 'NN'),
#  ('horribly', 'RB'),
#  ('vogue', 'JJ'),
#  ('images', 'NNS'),
#  ('matthew', 'VBP'),
#  ('modine', 'JJ'),
#  ('downing', 'VBG'),
#  ('bottle', 'JJ'),
#  ('jack', 'NN'),
#  ('daniels', 'NNS'),
#  ('beer', 'NN'),
#  ('wrapping', 'VBG'),
#  ('see', 'VBP'),
#  ('curtain', 'JJ'),
#  ('hotel', 'NN'),
#  ('room', 'NN'),
#  ('sea', 'NN'),
#  ('sea', 'NN'),
#  ('beautiful', 'JJ'),
#  ('sea', 'NN'),
#  ('cinematographer', 'NN'),
#  ('ken', 'VBN'),
#  ('kelsch', 'NNP'),
#  ('finds', 'VBZ'),
#  ('inconsistent', 'JJ'),
#  ('glory', 'NN'),
#  ('alternating', 'VBG'),
#  ('gorgeous', 'JJ'),
#  ('painterly', 'JJ'),
#  ('sunsets', 'NNS'),
#  ('docu', 'JJ'),
#  ('style', 'NN'),
#  ('sleaze', 'NN'),
#  ('back', 'RB'),
#  ('dennis', 'VBZ'),
#  ('hopper', 'NN'),
#  ('leering', 'VBG'),
#  ('girls', 'NNS'),
#  ('bathing', 'VBG'),
#  ('suits', 'NNS'),
#  ('yeah', 'RB'),
#  ('yeah', 'VBP'),
#  ('arrrghhh', 'NN'),
#  ('says', 'VBZ'),
#  ('mr', 'FW'),
#  ('hopper', 'JJR'),
#  ('dirty', 'NN'),
#  ('old', 'JJ'),
#  ('sod', 'NN'),
#  ('compulsive', 'JJ'),
#  ('viewing', 'NN'),
#  ('tacky', 'JJ'),
#  ('sort', 'NN'),
#  ('way', 'NN'),
#  ('leading', 'VBG'),
#  ('ridiculous', 'JJ'),
#  ('climax', 'JJ'),
#  ('modine', 'NN'),
#  ('seizes', 'NNS'),
#  ('control', 'NN'),
#  ('destiny', 'VBZ'),
#  ('cryptic', 'JJ'),
#  ('never', 'RB'),
#  ('fear', 'VBP'),
#  ('ferrara', 'JJ'),
#  ('finds', 'NNS'),
#  ('time', 'NN'),
#  ('female', 'JJ'),
#  ('full', 'JJ'),
#  ('frontal', 'JJ'),
#  ('nudity', 'NN'),
#  ('remind', 'VBP'),
#  ('us', 'PRP'),
#  ('picture', 'JJ'),
#  ('take', 'VB'),
#  ('yer', 'NN'),
#  ('clothes', 'NNS'),
#  ('kid', 'VBP'),
#  ('essential', 'JJ'),
#  ('depict', 'NN'),
#  ('inner', 'NN'),
#  ('maelstrom', 'IN'),
#  ('central', 'JJ'),
#  ('protagonist', 'JJ'),
#  ('visual', 'JJ'),
#  ...]

# %%
pos_doc[0][1]
# Out:
# 'RB'

# %%
def clean_data(words) :
#     for w in words:
#         if w[0].lower() not in stop:
#             words.append(w.lower())
    pos_doc = pos_tag(words)
#     print(pos_doc)
    for i in range(len(words)) :
        pos_doc[i]=list(pos_doc[i])
        if(pos_doc[i][1].startswith('JJ')):
            pos_doc[i][1] = 'a'
        elif(pos_doc[i][1].startswith('NN')):
            pos_doc[i][1] = 'n'
        elif(pos_doc[i][1].startswith('VB')):
            pos_doc[i][1] = 'v'
        print(pos_doc[i])
    for i in range(len(pos_doc)) :
        if(pos_doc[i][1]=='a' or pos_doc[i][1]=='n' or pos_doc[i][1]=='v'):
            pos_doc[i][0] = lem.lemmatize(pos_doc[i][0], pos = pos_doc[i][1])
            print(pos_doc[i][0])
    return pos_doc

# %%
clean = clean_data(all_words[3000])
# Out:
# ['c', 'v']
# ['a', 'DT']
# ['m', 'n']
# ['e', 'n']
# ['r', 'v']
# ['a', 'DT']
# c
# m
# e
# r

# %%
dist = nltk.FreqDist(clean)
features = dist.most_common(3000)
feature_words = [i[0] for i in features]
feature_words
# Out:
# [('a', 'DT'), ('c', 'v'), ('m', 'n'), ('e', 'n'), ('r', 'v')]

# %%
for i in range(len(clean)):
    clean[i]=tuple(clean[i])

# %%
def get_features(document):
    words = set(document)
    features = {}
    for w in feature_words:
        features[w] = (w in words)
    return features

# %%
training_data = [(get_features(a), b) for (a, b) in training_documents]
testing_data = [(get_features(a), b) for (a, b) in testing_documents]

# %%
classifier = nltk.NaiveBayesClassifier.train(training_data)

# %%
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#            ('john', 'v') = False             neg : pos    =      1.0 : 1.0
#         ('freeman', 'a') = False             neg : pos    =      1.0 : 1.0
#     ('throughout', 'IN') = False             neg : pos    =      1.0 : 1.0
#          ('become', 'v') = False             neg : pos    =      1.0 : 1.0
#          ('eating', 'v') = False             neg : pos    =      1.0 : 1.0
#            ('star', 'v') = False             neg : pos    =      1.0 : 1.0
#         ('graphic', 'a') = False             neg : pos    =      1.0 : 1.0
#            ('drew', 'v') = False             neg : pos    =      1.0 : 1.0
#            ('make', 'n') = False             neg : pos    =      1.0 : 1.0
#         ('imagine', 'n') = False             neg : pos    =      1.0 : 1.0
